# %%
#pip install buildingregulariser
# Out:
# Collecting buildingregulariser
#   Using cached buildingregulariser-0.1.10-py3-none-any.whl.metadata (5.8 kB)
# Collecting geopandas>=1.0.1 (from buildingregulariser)
#   Using cached geopandas-1.0.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting numpy>=2.2.4 (from buildingregulariser)
#   Downloading numpy-2.2.4-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Collecting scipy>=1.15.2 (from buildingregulariser)
#   Downloading scipy-1.15.2-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Collecting pyogrio>=0.7.2 (from geopandas>=1.0.1->buildingregulariser)
#   Downloading pyogrio-0.10.0-cp310-cp310-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: packaging in c:\users\user\anaconda3\envs\polygon\lib\site-packages (from geopandas>=1.0.1->buildingregulariser) (24.2)
# Collecting pandas>=1.4.0 (from geopandas>=1.0.1->buildingregulariser)
#   Downloading pandas-2.2.3-cp310-cp310-win_amd64.whl.metadata (19 kB)
# Collecting pyproj>=3.3.0 (from geopandas>=1.0.1->buildingregulariser)
#   Downloading pyproj-3.7.1-cp310-cp310-win_amd64.whl.metadata (31 kB)
# Collecting shapely>=2.0.0 (from geopandas>=1.0.1->buildingregulariser)
#   Downloading shapely-2.1.0-cp310-cp310-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\envs\polygon\lib\site-packages (from pandas>=1.4.0->geopandas>=1.0.1->buildingregulariser) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas>=1.4.0->geopandas>=1.0.1->buildingregulariser)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=1.4.0->geopandas>=1.0.1->buildingregulariser)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting certifi (from pyogrio>=0.7.2->geopandas>=1.0.1->buildingregulariser)
#   Downloading certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\envs\polygon\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas>=1.0.1->buildingregulariser) (1.17.0)
# Using cached buildingregulariser-0.1.10-py3-none-any.whl (18 kB)
# Using cached geopandas-1.0.1-py3-none-any.whl (323 kB)
# Downloading numpy-2.2.4-cp310-cp310-win_amd64.whl (12.9 MB)
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/12.9 MB 5.0 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.8/12.9 MB 4.6 MB/s eta 0:00:03
#    --------- ------------------------------ 3.1/12.9 MB 5.1 MB/s eta 0:00:02
#    ------------- -------------------------- 4.5/12.9 MB 5.4 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.8/12.9 MB 5.4 MB/s eta 0:00:02
#    --------------------- ------------------ 7.1/12.9 MB 5.5 MB/s eta 0:00:02
#    ------------------------- -------------- 8.1/12.9 MB 5.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 9.2/12.9 MB 5.4 MB/s eta 0:00:01
#    -------------------------------- ------- 10.5/12.9 MB 5.5 MB/s eta 0:00:01
#    ------------------------------------ --- 11.8/12.9 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------  12.8/12.9 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------  12.8/12.9 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 4.8 MB/s eta 0:00:00
# Downloading scipy-1.15.2-cp310-cp310-win_amd64.whl (41.2 MB)
#    ---------------------------------------- 0.0/41.2 MB ? eta -:--:--
#    - -------------------------------------- 1.0/41.2 MB 6.3 MB/s eta 0:00:07
#    -- ------------------------------------- 2.6/41.2 MB 6.6 MB/s eta 0:00:06
#    --- ------------------------------------ 3.9/41.2 MB 6.3 MB/s eta 0:00:06
#    ----- ---------------------------------- 5.2/41.2 MB 6.4 MB/s eta 0:00:06
#    ------ --------------------------------- 6.8/41.2 MB 6.4 MB/s eta 0:00:06
#    ------- -------------------------------- 8.1/41.2 MB 6.4 MB/s eta 0:00:06
#    --------- ------------------------------ 9.7/41.2 MB 6.4 MB/s eta 0:00:05
#    ---------- ----------------------------- 11.0/41.2 MB 6.4 MB/s eta 0:00:05
#    ----------- ---------------------------- 12.3/41.2 MB 6.4 MB/s eta 0:00:05
#    ------------- -------------------------- 13.6/41.2 MB 6.4 MB/s eta 0:00:05
#    -------------- ------------------------- 15.2/41.2 MB 6.4 MB/s eta 0:00:05
#    ---------------- ----------------------- 16.5/41.2 MB 6.4 MB/s eta 0:00:04
#    ----------------- ---------------------- 17.8/41.2 MB 6.4 MB/s eta 0:00:04
#    ------------------ --------------------- 19.4/41.2 MB 6.4 MB/s eta 0:00:04
#    -------------------- ------------------- 21.0/41.2 MB 6.5 MB/s eta 0:00:04
#    --------------------- ------------------ 22.3/41.2 MB 6.5 MB/s eta 0:00:03
#    ----------------------- ---------------- 23.9/41.2 MB 6.5 MB/s eta 0:00:03
#    ------------------------ --------------- 25.2/41.2 MB 6.5 MB/s eta 0:00:03
#    ------------------------- -------------- 26.7/41.2 MB 6.5 MB/s eta 0:00:03
#    --------------------------- ------------ 28.0/41.2 MB 6.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 29.6/41.2 MB 6.5 MB/s eta 0:00:02
#    ------------------------------ --------- 30.9/41.2 MB 6.5 MB/s eta 0:00:02
#    ------------------------------- -------- 32.2/41.2 MB 6.5 MB/s eta 0:00:02
#    -------------------------------- ------- 33.8/41.2 MB 6.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 35.1/41.2 MB 6.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 36.4/41.2 MB 6.5 MB/s eta 0:00:01
#    ------------------------------------ --- 37.7/41.2 MB 6.5 MB/s eta 0:00:01
#    ------------------------------------- -- 39.1/41.2 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------  40.4/41.2 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------  41.2/41.2 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------  41.2/41.2 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------  41.2/41.2 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------  41.2/41.2 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------- 41.2/41.2 MB 5.8 MB/s eta 0:00:00
# Downloading pandas-2.2.3-cp310-cp310-win_amd64.whl (11.6 MB)
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/11.6 MB 6.7 MB/s eta 0:00:02
#    --------- ------------------------------ 2.6/11.6 MB 6.3 MB/s eta 0:00:02
#    ------------- -------------------------- 3.9/11.6 MB 6.5 MB/s eta 0:00:02
#    ------------------ --------------------- 5.5/11.6 MB 6.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.8/11.6 MB 6.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.1/11.6 MB 6.5 MB/s eta 0:00:01
#    -------------------------------- ------- 9.4/11.6 MB 6.5 MB/s eta 0:00:01
#    ------------------------------------- -- 10.7/11.6 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.6 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------- 11.6/11.6 MB 5.9 MB/s eta 0:00:00
# Downloading pyogrio-0.10.0-cp310-cp310-win_amd64.whl (16.2 MB)
#    ---------------------------------------- 0.0/16.2 MB ? eta -:--:--
#    -- ------------------------------------- 1.0/16.2 MB 7.1 MB/s eta 0:00:03
#    ------ --------------------------------- 2.6/16.2 MB 6.9 MB/s eta 0:00:02
#    --------- ------------------------------ 3.9/16.2 MB 6.7 MB/s eta 0:00:02
#    ------------ --------------------------- 5.2/16.2 MB 6.6 MB/s eta 0:00:02
#    ---------------- ----------------------- 6.8/16.2 MB 6.6 MB/s eta 0:00:02
#    -------------------- ------------------- 8.1/16.2 MB 6.6 MB/s eta 0:00:02
#    ----------------------- ---------------- 9.4/16.2 MB 6.5 MB/s eta 0:00:02
#    -------------------------- ------------- 10.7/16.2 MB 6.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 12.1/16.2 MB 6.5 MB/s eta 0:00:01
#    --------------------------------- ------ 13.6/16.2 MB 6.5 MB/s eta 0:00:01
#    ------------------------------------ --- 14.9/16.2 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------  16.0/16.2 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------- 16.2/16.2 MB 6.0 MB/s eta 0:00:00
# Downloading pyproj-3.7.1-cp310-cp310-win_amd64.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    -------- ------------------------------- 1.3/6.3 MB 6.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 2.6/6.3 MB 6.6 MB/s eta 0:00:01
#    -------------------- ------------------- 3.1/6.3 MB 6.4 MB/s eta 0:00:01
#    -------------------------- ------------- 4.2/6.3 MB 5.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 5.5/6.3 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 5.1 MB/s eta 0:00:00
# Downloading shapely-2.1.0-cp310-cp310-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------------------ --------- 1.3/1.7 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 5.1 MB/s eta 0:00:00
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading certifi-2025.1.31-py3-none-any.whl (166 kB)
# Installing collected packages: pytz, tzdata, numpy, certifi, shapely, scipy, pyproj, pyogrio, pandas, geopandas, buildingregulariser
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
# Successfully installed buildingregulariser-0.1.10 certifi-2025.1.31 geopandas-1.0.1 numpy-2.2.4 pandas-2.2.3 pyogrio-0.10.0 pyproj-3.7.1 pytz-2025.2 scipy-1.15.2 shapely-2.1.0 tzdata-2025.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'C:\Users\User\anaconda3\envs\polygon\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pyproj.exe is installed in 'C:\Users\User\anaconda3\envs\polygon\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import geopandas as gpd
from buildingregulariser import regularize_geodataframe

# Load your building footprints
buildings = gpd.read_file("results/heliopolis-multipoligono.gpkg")

# Regularize the building footprints
regularized_buildings = regularize_geodataframe(
    buildings, 
)

# Save the results
regularized_buildings.to_file("results/heliopolis_regularizado.gpkg")
